# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool, ToolRuntime

@tool
def read_email(runtime: ToolRuntime) -> str:
    """Read an email from the given address."""
    # take email from state
    return runtime.state["email"]

@tool
def send_email(body: str) -> str:
    """Send an email to the given address with the given subject and body."""
    # fake email sending
    return f"Email sent"

# %%
from langchain.agents import create_agent, AgentState
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

class EmailState(AgentState):
    email: str

agent = create_agent(
    model="gpt-5-nano",
    tools=[read_email, send_email],
    state_schema=EmailState,
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "read_email": False,
                "send_email": True,
            },
            description_prefix="Tool execution requires approval",
        ),
    ],
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {
        "messages": [HumanMessage(content="Please read my email and send a response immediately. Send the reply now in the same thread.")],
        "email": "Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John."
    },
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Hi '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           'Thanks '
#                                                                           'for '
#                                                                           'the '
#                                                                           'heads '
#                                                                           'up. '
#                                                                           'I’m '
#                                                                           'happy '
#                                                                           'to '
#                                                                           'reschedule. '
#                                                                           'Would '
#                                                                           'tomorrow '
#                                                                           'at '
#                                                                           '11:00 '
#                                                                           'AM '
#                                                                           'or '
#                                                                           '2:00 '
#                                                                           'PM '
#                                                                           'work '
#                                                                           'for '
#                                                                           'you? '
#                                                                           'If '
#                                                                           'those '
#                                                                           'times '
#                                                                           'don’t '
#                                                                           'suit, '
#                                                                           'please '
#                                                                           'suggest '
#                                                                           'a '
#                                                                           'time '
#                                                                           'that '
#                                                                           'does.\n'
#                                                                           '\n'
#                                                                           'Best '
#                                                                           'regards,\n'
#                                                                           'Seán'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'body': "
#                                                                         "'Hi "
#                                                                         'John,\\n\\nThanks '
#                                                                         'for '
#                                                                         'the '
#                                                                         'heads '
#                                                                         'up. '
#                                                                         'I’m '
#                                                                         'happy '
#                                                                         'to '
#                                                                         'reschedule. '
#                                                                         'Would '
#                                                                         'tomorrow '
#                                                                         'at '
#                                                                         '11:00 '
#                                                                         'AM or '
#                                                                         '2:00 '
#                                                                         'PM '
#                                                                         'work '
#                                                                         'for '
#                                                                         'you? '
#                                                                         'If '
#                                                                         'those '
#                                                                         'times '
#                                                                         'don’t '
#                                                                         'suit, '
#                                                                         'please '
#                                                                         'suggest '
#                                                                         'a '
#                                                                         'time '
#                                                                         'that '
#                                                                         'does.\\n\\nBest '
#                                                                         "regards,\\nSeán'}",
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='3a24d3ccae7efe86cb30823964cabd3c')],
#  'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='831d5dfa-9dd3-4ac1-ad78-018b60814e49'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 167, 'total_tokens': 762, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8M5x5heXsqpaAfuKkqpaHEpAZ55', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-5e69-7b62-81c7-8a2778943db2-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_cfmkwfQrrJw5HEfjLdQHBTmN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 595, 'total_tokens': 762, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='a2b99868-d574-40b5-98cd-e025e086d823', tool_call_id='call_cfmkwfQrrJw5HEfjLdQHBTmN'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1232, 'prompt_tokens': 214, 'total_tokens': 1446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8MAjTm6S45c1kdQpZcHHaW0WEfx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-7578-74a3-ad9f-1751349de491-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán'}, 'id': 'call_XqpOMPzByk06W8pkPAn7yFhA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 1232, 'total_tokens': 1446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}})]}

# %%
print(response['__interrupt__'])
# Out:
# [Interrupt(value={'action_requests': [{'name': 'send_email', 'args': {'body': 'Hi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán'}, 'description': "Tool execution requires approval\n\nTool: send_email\nArgs: {'body': 'Hi John,\\n\\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\\n\\nBest regards,\\nSeán'}"}], 'review_configs': [{'action_name': 'send_email', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='3a24d3ccae7efe86cb30823964cabd3c')]

# %%
# Access just the 'body' argument from the tool call
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi John,
#
# Thanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.
#
# Best regards,
# Seán

# %% [markdown]
# ## Approve

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}
    ), 
    config=config # Same thread ID to resume the paused conversation
)

pprint(response)
# Out:
# {'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='831d5dfa-9dd3-4ac1-ad78-018b60814e49'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 167, 'total_tokens': 762, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8M5x5heXsqpaAfuKkqpaHEpAZ55', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-5e69-7b62-81c7-8a2778943db2-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_cfmkwfQrrJw5HEfjLdQHBTmN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 595, 'total_tokens': 762, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='a2b99868-d574-40b5-98cd-e025e086d823', tool_call_id='call_cfmkwfQrrJw5HEfjLdQHBTmN'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1232, 'prompt_tokens': 214, 'total_tokens': 1446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8MAjTm6S45c1kdQpZcHHaW0WEfx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-7578-74a3-ad9f-1751349de491-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán'}, 'id': 'call_XqpOMPzByk06W8pkPAn7yFhA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 1232, 'total_tokens': 1446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#               ToolMessage(content='Email sent', name='send_email', id='8435f2b9-7144-44e3-bde3-44f638f4259f', tool_call_id='call_XqpOMPzByk06W8pkPAn7yFhA'),
#               AIMessage(content='I’ve read your email and sent a reply in the same thread. Here’s what I wrote:\n\nHi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán\n\nIf you’d like any changes to the proposed times or tone, tell me and I can adjust.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 301, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8NLs5fu44KiCF4whEZuRxAPjkR8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdbd1-8f6e-76f1-ba4c-fcb47756f44c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 301, 'output_tokens': 97, 'total_tokens': 398, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Reject

# %%
response = agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "reject",
                    # An explanation of why the request was rejected
                    "message": "No please sign off - Your merciful leader, Seán."
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)
# Out:
# {'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='831d5dfa-9dd3-4ac1-ad78-018b60814e49'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 167, 'total_tokens': 762, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8M5x5heXsqpaAfuKkqpaHEpAZ55', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-5e69-7b62-81c7-8a2778943db2-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_cfmkwfQrrJw5HEfjLdQHBTmN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 595, 'total_tokens': 762, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='a2b99868-d574-40b5-98cd-e025e086d823', tool_call_id='call_cfmkwfQrrJw5HEfjLdQHBTmN'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1232, 'prompt_tokens': 214, 'total_tokens': 1446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8MAjTm6S45c1kdQpZcHHaW0WEfx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-7578-74a3-ad9f-1751349de491-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán'}, 'id': 'call_XqpOMPzByk06W8pkPAn7yFhA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 1232, 'total_tokens': 1446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#               ToolMessage(content='Email sent', name='send_email', id='8435f2b9-7144-44e3-bde3-44f638f4259f', tool_call_id='call_XqpOMPzByk06W8pkPAn7yFhA'),
#               AIMessage(content='I’ve read your email and sent a reply in the same thread. Here’s what I wrote:\n\nHi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán\n\nIf you’d like any changes to the proposed times or tone, tell me and I can adjust.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 301, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8NLs5fu44KiCF4whEZuRxAPjkR8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdbd1-8f6e-76f1-ba4c-fcb47756f44c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 301, 'output_tokens': 97, 'total_tokens': 398, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
#
# KeyError: '__interrupt__'

# %% [markdown]
# ## Edit

# %%
response = agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "edit",
                    # Edited action with tool name and args
                    "edited_action": {
                        # Tool name to call.
                        # Will usually be the same as the original action.
                        "name": "send_email",
                        # Arguments to pass to the tool.
                        "args": {"body": "This is the last straw, you're fired!"},
                    }
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)
# Out:
# {'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='831d5dfa-9dd3-4ac1-ad78-018b60814e49'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 167, 'total_tokens': 762, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8M5x5heXsqpaAfuKkqpaHEpAZ55', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-5e69-7b62-81c7-8a2778943db2-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_cfmkwfQrrJw5HEfjLdQHBTmN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 595, 'total_tokens': 762, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='a2b99868-d574-40b5-98cd-e025e086d823', tool_call_id='call_cfmkwfQrrJw5HEfjLdQHBTmN'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1232, 'prompt_tokens': 214, 'total_tokens': 1446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8MAjTm6S45c1kdQpZcHHaW0WEfx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbd0-7578-74a3-ad9f-1751349de491-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán'}, 'id': 'call_XqpOMPzByk06W8pkPAn7yFhA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 1232, 'total_tokens': 1446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#               ToolMessage(content='Email sent', name='send_email', id='8435f2b9-7144-44e3-bde3-44f638f4259f', tool_call_id='call_XqpOMPzByk06W8pkPAn7yFhA'),
#               AIMessage(content='I’ve read your email and sent a reply in the same thread. Here’s what I wrote:\n\nHi John,\n\nThanks for the heads up. I’m happy to reschedule. Would tomorrow at 11:00 AM or 2:00 PM work for you? If those times don’t suit, please suggest a time that does.\n\nBest regards,\nSeán\n\nIf you’d like any changes to the proposed times or tone, tell me and I can adjust.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 301, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI8NLs5fu44KiCF4whEZuRxAPjkR8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdbd1-8f6e-76f1-ba4c-fcb47756f44c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 301, 'output_tokens': 97, 'total_tokens': 398, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
