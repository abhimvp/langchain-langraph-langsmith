# %% [markdown]
# email agent
# - authenticates user
#     - only then are they allowed into the "inbox"
#     - dynamic tools and prompt on the condition of there being an email and password in state that match hardcoded
# - checks "inbox"
#     - email in tool
# - sends emails
#     - human in the loop

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "julie@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:

    """Allow read inbox and send email tools only if user provides correct email and password"""

    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools) 
    return handler(request)

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = "You are a helpful assistant that can check the inbox and send emails."
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

agent = create_agent(
    "gpt-5-nano",
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="draft 1")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)
# Out:
# Sure—do you want Draft 1 for something specific? If you’re aiming for an authentication-related draft, here’s a ready-to-use Draft 1 for a simple email/password login API. Let me know if you want it tailored to a particular language, framework, or platform.
#
# Draft 1: Simple email/password login API specification
#
# Objective
# - Provide a minimal, secure login mechanism that issues a JWT access token on successful authentication.
#
# Scope
# - Supports login via email and password.
# - Returns a signed JWT access token and basic user info.
# - Includes basic rate limiting, validation, and error handling.
# - Optional: refresh token workflow (to be implemented if needed).
#
# Endpoints
# - POST /auth/login
#   - Purpose: Authenticate user and return access token.
#   - Request (JSON):
#     - email: string (required)
#     - password: string (required)
#   - Responses:
#     - 200 OK
#       - Body:
#         - token: string (JWT)
#         - expires_in: integer (seconds)
#         - user: { id: string, email: string, name: string }
#     - 400 Bad Request
#       - Body: { error: "invalid_request", message: "Email and password are required." }
#     - 401 Unauthorized
#       - Body: { error: "invalid_credentials", message: "Email or password is incorrect." }
#     - 429 Too Many Requests
#       - Body: { error: "rate_limited", message: "Too many login attempts. Please try again later." }
# - POST /auth/logout
#   - Purpose: Invalidate token (if token revocation is supported on server; otherwise no-op for stateless JWT).
#   - Headers: Authorization: Bearer <token>
#   - Responses:
#     - 204 No Content
#     - 401 Unauthorized (invalid/expired token)
# - POST /auth/refresh (optional)
#   - Purpose: Exchange a refresh token for a new access token.
#   - Request (JSON):
#     - refresh_token: string (required)
#   - Responses:
#     - 200 OK
#       - Body: { token: string, expires_in: integer }
#     - 400 Bad Request
#     - 401 Unauthorized
#
# Data models
# - User
#   - id: string
#   - email: string
#   - name: string
# - Token response
#   - token: string
#   - expires_in: integer (seconds)
#   - user: { id, email, name }
# - Optional refresh token model
#   - refresh_token: string
#   - token_type: string (e.g., "Bearer")
#   - expires_in: integer
#
# Security considerations
# - Password storage: hash passwords with a strong algorithm (e.g., bcrypt) and unique salt per user.
# - Token security: sign JWTs using HS256 or RS256 with a strong secret/key pair; set reasonable expiration (e.g., 15–60 minutes).
# - Token handling: use HTTPS, short token lifetimes, consider refresh tokens for longer sessions.
# - Rate limiting: protect against brute-force attempts (e.g., exponential backoff, IP-based rate limits, account lockout policies).
# - Input validation: validate email format; enforce minimum password length; normalize inputs.
# - Logging: avoid echoing passwords in logs; log authentication events at appropriate levels.
#
# Validation rules
# - Email must be a valid email address format.
# - Password must be at least 8 characters (adjust as needed).
# - Non-empty email and password required.
#
# Error handling guidance
# - 400: Missing fields or invalid format.
# - 401: Incorrect credentials or invalid/expired token.
# - 429: Too many failed attempts; implement backoff or CAPTCHA if needed.
# - 5xx: Unexpected server error; return generic message to avoid leaking details.
#
# Testing criteria
# - Unit tests for:
#   - Email/Password validation
#   - Password hashing/verification
#   - JWT generation and verification
# - Integration tests for:
#   - Successful login returns token and user info
#   - Failed login returns 401 with proper error
#   - Rate-limiting behavior
#   - Optional refresh flow (if implemented)
#
# Example flow
# - Client sends POST /auth/login with:
#   {
#     "email": "user@example.com",
#     "password": "p@ssw0rd"
#   }
# - Server responds with:
#   {
#     "token": "<JWT>",
#     "expires_in": 3600,
#     "user": {
#       "id": "abc123",
#       "email": "user@example.com",
#       "name": "User Name"
#     }
#   }
#
# Would you like this tailored to a specific tech stack (e.g., Node.js/Express, Python/Flask, Java/Spring Boot), include a refresh token flow, or expand into a full API spec with schemas and test cases? If you have a target framework or any constraints, share them and I’ll adjust Draft 1 accordingly.

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
#
# KeyError: '__interrupt__'

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)
# Out:
# Sure—do you want Draft 1 for something specific? If you’re aiming for an authentication-related draft, here’s a ready-to-use Draft 1 for a simple email/password login API. Let me know if you want it tailored to a particular language, framework, or platform.
#
# Draft 1: Simple email/password login API specification
#
# Objective
# - Provide a minimal, secure login mechanism that issues a JWT access token on successful authentication.
#
# Scope
# - Supports login via email and password.
# - Returns a signed JWT access token and basic user info.
# - Includes basic rate limiting, validation, and error handling.
# - Optional: refresh token workflow (to be implemented if needed).
#
# Endpoints
# - POST /auth/login
#   - Purpose: Authenticate user and return access token.
#   - Request (JSON):
#     - email: string (required)
#     - password: string (required)
#   - Responses:
#     - 200 OK
#       - Body:
#         - token: string (JWT)
#         - expires_in: integer (seconds)
#         - user: { id: string, email: string, name: string }
#     - 400 Bad Request
#       - Body: { error: "invalid_request", message: "Email and password are required." }
#     - 401 Unauthorized
#       - Body: { error: "invalid_credentials", message: "Email or password is incorrect." }
#     - 429 Too Many Requests
#       - Body: { error: "rate_limited", message: "Too many login attempts. Please try again later." }
# - POST /auth/logout
#   - Purpose: Invalidate token (if token revocation is supported on server; otherwise no-op for stateless JWT).
#   - Headers: Authorization: Bearer <token>
#   - Responses:
#     - 204 No Content
#     - 401 Unauthorized (invalid/expired token)
# - POST /auth/refresh (optional)
#   - Purpose: Exchange a refresh token for a new access token.
#   - Request (JSON):
#     - refresh_token: string (required)
#   - Responses:
#     - 200 OK
#       - Body: { token: string, expires_in: integer }
#     - 400 Bad Request
#     - 401 Unauthorized
#
# Data models
# - User
#   - id: string
#   - email: string
#   - name: string
# - Token response
#   - token: string
#   - expires_in: integer (seconds)
#   - user: { id, email, name }
# - Optional refresh token model
#   - refresh_token: string
#   - token_type: string (e.g., "Bearer")
#   - expires_in: integer
#
# Security considerations
# - Password storage: hash passwords with a strong algorithm (e.g., bcrypt) and unique salt per user.
# - Token security: sign JWTs using HS256 or RS256 with a strong secret/key pair; set reasonable expiration (e.g., 15–60 minutes).
# - Token handling: use HTTPS, short token lifetimes, consider refresh tokens for longer sessions.
# - Rate limiting: protect against brute-force attempts (e.g., exponential backoff, IP-based rate limits, account lockout policies).
# - Input validation: validate email format; enforce minimum password length; normalize inputs.
# - Logging: avoid echoing passwords in logs; log authentication events at appropriate levels.
#
# Validation rules
# - Email must be a valid email address format.
# - Password must be at least 8 characters (adjust as needed).
# - Non-empty email and password required.
#
# Error handling guidance
# - 400: Missing fields or invalid format.
# - 401: Incorrect credentials or invalid/expired token.
# - 429: Too many failed attempts; implement backoff or CAPTCHA if needed.
# - 5xx: Unexpected server error; return generic message to avoid leaking details.
#
# Testing criteria
# - Unit tests for:
#   - Email/Password validation
#   - Password hashing/verification
#   - JWT generation and verification
# - Integration tests for:
#   - Successful login returns token and user info
#   - Failed login returns 401 with proper error
#   - Rate-limiting behavior
#   - Optional refresh flow (if implemented)
#
# Example flow
# - Client sends POST /auth/login with:
#   {
#     "email": "user@example.com",
#     "password": "p@ssw0rd"
#   }
# - Server responds with:
#   {
#     "token": "<JWT>",
#     "expires_in": 3600,
#     "user": {
#       "id": "abc123",
#       "email": "user@example.com",
#       "name": "User Name"
#     }
#   }
#
# Would you like this tailored to a specific tech stack (e.g., Node.js/Express, Python/Flask, Java/Spring Boot), include a refresh token flow, or expand into a full API spec with schemas and test cases? If you have a target framework or any constraints, share them and I’ll adjust Draft 1 accordingly.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='6083d572-69d5-4cdd-99bd-88e3a5b78a0f'),
#               AIMessage(content='Sure—do you want Draft 1 for something specific? If you’re aiming for an authentication-related draft, here’s a ready-to-use Draft 1 for a simple email/password login API. Let me know if you want it tailored to a particular language, framework, or platform.\n\nDraft 1: Simple email/password login API specification\n\nObjective\n- Provide a minimal, secure login mechanism that issues a JWT access token on successful authentication.\n\nScope\n- Supports login via email and password.\n- Returns a signed JWT access token and basic user info.\n- Includes basic rate limiting, validation, and error handling.\n- Optional: refresh token workflow (to be implemented if needed).\n\nEndpoints\n- POST /auth/login\n  - Purpose: Authenticate user and return access token.\n  - Request (JSON):\n    - email: string (required)\n    - password: string (required)\n  - Responses:\n    - 200 OK\n      - Body:\n        - token: string (JWT)\n        - expires_in: integer (seconds)\n        - user: { id: string, email: string, name: string }\n    - 400 Bad Request\n      - Body: { error: "invalid_request", message: "Email and password are required." }\n    - 401 Unauthorized\n      - Body: { error: "invalid_credentials", message: "Email or password is incorrect." }\n    - 429 Too Many Requests\n      - Body: { error: "rate_limited", message: "Too many login attempts. Please try again later." }\n- POST /auth/logout\n  - Purpose: Invalidate token (if token revocation is supported on server; otherwise no-op for stateless JWT).\n  - Headers: Authorization: Bearer <token>\n  - Responses:\n    - 204 No Content\n    - 401 Unauthorized (invalid/expired token)\n- POST /auth/refresh (optional)\n  - Purpose: Exchange a refresh token for a new access token.\n  - Request (JSON):\n    - refresh_token: string (required)\n  - Responses:\n    - 200 OK\n      - Body: { token: string, expires_in: integer }\n    - 400 Bad Request\n    - 401 Unauthorized\n\nData models\n- User\n  - id: string\n  - email: string\n  - name: string\n- Token response\n  - token: string\n  - expires_in: integer (seconds)\n  - user: { id, email, name }\n- Optional refresh token model\n  - refresh_token: string\n  - token_type: string (e.g., "Bearer")\n  - expires_in: integer\n\nSecurity considerations\n- Password storage: hash passwords with a strong algorithm (e.g., bcrypt) and unique salt per user.\n- Token security: sign JWTs using HS256 or RS256 with a strong secret/key pair; set reasonable expiration (e.g., 15–60 minutes).\n- Token handling: use HTTPS, short token lifetimes, consider refresh tokens for longer sessions.\n- Rate limiting: protect against brute-force attempts (e.g., exponential backoff, IP-based rate limits, account lockout policies).\n- Input validation: validate email format; enforce minimum password length; normalize inputs.\n- Logging: avoid echoing passwords in logs; log authentication events at appropriate levels.\n\nValidation rules\n- Email must be a valid email address format.\n- Password must be at least 8 characters (adjust as needed).\n- Non-empty email and password required.\n\nError handling guidance\n- 400: Missing fields or invalid format.\n- 401: Incorrect credentials or invalid/expired token.\n- 429: Too many failed attempts; implement backoff or CAPTCHA if needed.\n- 5xx: Unexpected server error; return generic message to avoid leaking details.\n\nTesting criteria\n- Unit tests for:\n  - Email/Password validation\n  - Password hashing/verification\n  - JWT generation and verification\n- Integration tests for:\n  - Successful login returns token and user info\n  - Failed login returns 401 with proper error\n  - Rate-limiting behavior\n  - Optional refresh flow (if implemented)\n\nExample flow\n- Client sends POST /auth/login with:\n  {\n    "email": "user@example.com",\n    "password": "p@ssw0rd"\n  }\n- Server responds with:\n  {\n    "token": "<JWT>",\n    "expires_in": 3600,\n    "user": {\n      "id": "abc123",\n      "ema ...
