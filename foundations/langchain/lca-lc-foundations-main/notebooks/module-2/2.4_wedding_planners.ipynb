# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='228db77c-4a1b-47fd-8253-c95b0cfad758'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 293, 'prompt_tokens': 336, 'total_tokens': 629, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI7jTGyQrdpoVx7FeoaNfKhDhqaGK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbab-d9ec-7f82-a2b1-1653e2e50b24-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_Tr6akZPO7RecQ8ekiibaj0PB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 293, 'total_tokens': 629, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='dd8f703b-ce9d-4064-a961-c6a08c5d61e9', tool_call_id='call_Tr6akZPO7RecQ8ekiibaj0PB'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 446, 'prompt_tokens': 381, 'total_tokens': 827, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI7jYf7pd5a5pntucI7hysqewcL0G', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdbab-ebf6-7953-b413-cf7ae5650389-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_nqGODX7vXzKTMjJGyeVCHdfi', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_WZlvguwn6TVOaBGuXCLosGJt', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_cngNhLgTwE6kIVZvSOh0MKNN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 381, 'output_tokens': 446, 'total_tokens': 827, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content='Here are the best one-way economy options from London to Paris based on price, shortest duration, and a May timing that’s nice for a wedding trip. All are single tickets.\n\n| Route | Times (local) and duration | Cabin | Price (EUR) | Book link |\n|---|---|---|---:|---|\n| LTN → CDG (direct) | 13 May 2026, 06:10 → 08:35, duration 1h25m | Economy | 37 | https://on.kiwi.com/NHMV9y |\n| LGW → CDG (direct) | 13 May 2026, 16:10 → 18:30, duration 1h20m | Economy | 44 | https://on.kiwi.com/qsC6F4 |\n| LGW → CDG (direct) | 12 May 2026, 16:50 → 18:10, duration 1h20m | Economy | 44 | https://on.kiwi.com/Qiy1Q2 |\n| LGW → CDG (direct) | 15 May 2026, 18:00 → 21:20, duration 1h20m | Economy | 44 | https://on.kiwi.com/lXm7Ce |\n| SEN → CDG (direct) | 14 May 2026, 10:10 → 12:20, duration 1h10m | Economy | 49 | https://on.kiwi.com/tygfQj |\n| STN → CDG (direct) | 15 May 2026, 16:00 → 19:10, duration 1h10m | Economy | 54 | https://on.kiwi.com/sVFB7T |\n| LTN → CDG (direct) | 18 May 2026, 19:40 → 22:00, duration 1h20m | Economy | 44 | https://on.kiwi.com/P23g0A |\n\nNotes\n- These are all one-way flights from London airports (LTN, LGW, STN, SEN) to Paris CDG, in economy.\n- The cheapest option is 37 EUR (LTN → CDG, 13 May). If you’re flexible, that’s a standout value.\n- Shortest-duration options (around 1h10–1h20) include several 1h10m and 1h20m direct routes.\n- May is a lovely time for a Paris wedding trip—pleasant temps and longer daylight hours. If you’re planning a wedding-season trip, late May (and early June) tends to be especially nice.\n\nFun fact about Paris: The City of Light got its nickname not just from its early adoption of street lighting, but also because it has long been a beacon of culture, art, and ideas. Enjoy your trip!', name='search_flights', id='283448c2-31c5-429d-b65e-e97225c819fa', tool_call_id='call_nqGODX7vXzKTMjJGyeVCHdfi'),
#               ToolMessage(content='Here are Paris wedding venues that can accommodate about 100 guests, prioritized by explicit 100-person capacity and supported by the data I found. I’ve noted price and review details where available.\n\nBest exact-100 capacity option (lowest price data)\n- Une Salle Paris (Salle 100 Personnes)\n  - Capacity: exactly 100 guests (salle listed as 100 personnes)\n  - Price: from about €1,500 to €5,000\n  - Reviews: not clearly shown on the listing snippet\n  - Source: unesalleaparis.com (Location Salle Paris : +1000 Espaces Uniques; specific 100-person listing cited in the search results)\n\nOther Paris options that can host around 100 (useful if exact 100 is not strictly required)\n- Native Spaces – Paris Event Space\n  - Capacity: up to 100 guests\n  - Price: not shown in the listing\n  - Reviews: not shown in the listing\n  - Source: native-spaces.com (“Paris Event Space for 100 Guests | Private Venue Rental”)\n\n- Le Philanthro-Lab (via SnapEvent)\n  - Capacity: not stated in the snippet, but listed as a Paris event space on SnapEvent\n  - Price: from €6,750 HT (varies by package)\n  - Reviews: 5/5 from 2 reviews on the listing\n  - Source: snapevent.fr (Edition showing Le Philanthro-Lab with price and reviews)\n\n- Paris venues listed for up to 100 guests (general listings)\n  - Capacity: generally up to 100 (seated) or 100-ish (varies by venue)\n  - Price: varies; some listings show lower-end options around €2,000–€3,000 or higher depending on package\n  - Reviews: varies by listing\n  - Sources: \n    - Mariages.net (article “Les 10 meilleures SALLES DE MARIAGE à Paris (jusqu’à 100 convives)”)\n    - 1001salles / UneSalleAParis-type pages (general guidance on capacity and pricing)\n\nNotes and guidance\n- If strict exact capacity of 100 seated is non-negotiable, Une Salle Paris is the clearest match with explicit “100 personnes” in the listing and a published price range.\n- If you’re flexible around exactly 100 and want strong reviews, the SnapEvent option Le Philanthro-Lab has visible guest reviews (5/5 from several reviews) and a concrete starting price, though it’s on the higher end.\n- For potentially lower-cost or more modular options, check Paris venue marketplaces (Native Spaces, 1001salles, Mariages.net) which list spaces that can accommodate around 100 guests, but you’ll usually need to contact venues for exact seated capacity and updated pricing.\n\nWould you like me to narrow this to a stricter list of only spaces with confirmed exact seating for 100 (with current quotes), or expand to include near-100-capacity venues with strong reviews and good value?', name='search_venues', id='ee2d77fa-37b5-432f-b2ad-d06efdd539c5', tool_call_id='call_WZlvguwn6TVOaBGuXCLosGJt'),
#               ToolMessage(content='Here’s a curated jazz-themed wedding playlist pulled from the Jazz catalog. It aims for a classy, relaxed vibe for dinner with a touch of bossa nova, then a gentle mood lift without being too long.\n\n1) Garota De Ipanema — Antonio Carlos Jobim — Album: Warmer 25 Anos — 4:45\n2) Desafinado — Antonio Carlos Jobim — Album: Warner 25 Anos — 3:05\n3) Corcovado (Quiet Nights Of Quiet Stars) — Antonio Carlos Jobim — Album: Warner 25 Anos — 3:26\n4) Dindi — Antonio Carlos Jobim — Album: Warmer 25 Anos — 4:13\n5) O Boto (Bôto) — Antonio Carlos Jobim — Album: Warner 25 Anos — 6:07\n6) Samba De Uma Nota Só (One Note Samba) — Antonio Carlos Jobim — Album: Warner 25 Anos — 2:17\n7) Se Todos Fossem Iguais A Você (Instrumental) — Antonio Carlos Jobim — Album: Warner 25 Anos — 2:15\n8) Angela — Antonio Carlos Jobim — Album: Worlds — 2:49\n9) Canta, Canta Mais — Antonio Carlos Jobim — Album: Quiet Songs — 4:32\n10) Ligia — Antonio Carlos Jobim — Album: Warner 25 Anos — 4:12\n11) Outra Vez — Antonio Carlos Jobim — Album: Warner 25 Anos — 2:07\n12) Por Causa De Você — Antonio Carlos Jobim — Album: Warner 25 Anos — 2:50\n13) Do What Cha Wanna — Billy Cobham — Album: The Best Of Billy Cobham — 4:34\n14) Moon Germs — Billy Cobham — Album: The Best Of Billy Cobham — 4:54\n15) Quadrant — Billy Cobham — Album: The Best Of Billy Cobham — 4:22\n\nTotal duration: 56 minutes 28 seconds\nTotal cost: $14.85 (15 tracks × $0.99 each)\n\nNotes on vibe and flow:\n- Starts with warm bossa nova tunes for a classy, relaxed atmosphere.\n- Mixes vocal and instrumental pieces for variety without harsh tempo shifts.\n- Ends with a gentle, upbeat brainer to keep the mood light without overpowering conversations.\n\nWould you like me to:\n- Swap in more classic swing/standards for a lively dancing vibe?\n- Shorten this to around 40–45 minutes for a dinner-only set, or extend to 80–90 minutes with more tracks?\n- Export this as a CSV/playlist file for your DJ or streaming service?', name='suggest_playlist', id='677b3ac8-126f-4202-8b7e-5fbc0cb166a8', tool_call_id='call_cngNhLgTwE6kIVZvSOh0MKNN'),
#               AIMessage(content='Fantastic—we’ve got a clear picture: you’re in London, you want a wedding in Paris for 100 guests with a jazz vibe. I’ve pulled together practical options and next steps to lock this in.\n\nWhat I have gathered and updated\n- Origin: London\n- Destination: Paris\n- Guest count: 100\n- Music mood: Jazz (with a tasteful dinner set, optional live jazz or DJ)\n\nTravel options (planning for guests)\n- Best value direct options from London to Paris (May timing)\n  - LTN → CDG: 13 May 2026, 06:10–08:35, 1h25m, Economy, ~€37, Kiwi booking link: https://on.kiwi.com/NHMV9y\n  - LGW → CDG: 13 May 2026, 16:10–18:30, 1h20m, Economy, ~€44, Kiwi booking link: https://on.kiwi.com/qsC6F4\n  - LGW → CDG: 12 May 2026, 16:50–18:10, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/Qiy1Q2\n  - LGW → CDG: 15 May 2026, 18:00–21:20, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/lXm7Ce\n  - SEN → CDG: 14 May 2026, 10:10–12:20, 1h10m, Economy, ~€49, Kiwi: https://on.kiwi.com/tygfQj\n  - STN → CDG: 15 May 2026, 16:00–19:10, 1h10m, Economy, ~€54, Kiwi: https://on.kiwi.com/sVFB7T\n  - LTN → CDG: 18 May 2026, 19:40–22:00, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/P23g0A\n- Note: These are one-way, economy fare options suitable for a May wedding trip. If you’d rather secure a group block for guests or need specific dates, I can shift to a group quote or suggest alternate dates.\n\nVenue options in Paris for ~100 guests (with capacity and pricing hints)\n- Primary match: Une Salle Paris (Salle 100 Personnes)\n  - Capacity: exactly 100 guests\n  - Price: from ~€1,500 to ~€5,000 (range depends on package; need current quotes)\n  - Source: unesalleaparis.com\n  - Why consider: explicit 100-person capacity in listing; tends to align well with strict guest count\n- Strong near-100 options:\n  - Native Spaces – Paris Event Space\n    - Capacity: up to 100\n    - Price: not listed online (requires direct quote)\n    - Source: native-spaces.com\n  - Le Philanthro-Lab (via SnapEvent)\n    - Capacity: not stated in snippet\n    - Price: from ~€6,750 HT (varies by package)\n    - Reviews: some positive notes\n    - Source: snapevent.fr\n- Additional venues often listed for up to 100 guests (useful if exact capacity is flexible)\n  - Paris venues via Mariages.net and 1001salles, etc. (vary by venue and package)\nWhat I’d recommend now\n- Primary option to proceed with: Une Salle Paris (Salle 100 Personnes)\n  - Pros: explicit 100-person capacity, potentially the most straightforward for 100 guests\n  - Cons: price varies; need current quotes and date availability\n- Secondary option if you want flexibility or a different vibe: Native Spaces – Paris Event Space\n  - Pros: can host up to 100; modern, modular spaces\n  - Cons: exact capacity and pricing require a direct quote\nWould you like me to:\n- Contact Une Salle Paris and Native Spaces for availability and formal quotes for your preferred May dates?\n- Or would you prefer I also explore a live jazz venue option (jazz quartet/ensemble in a ceremony-dinner format) as part of the venue plan?\n\nMusic plan (jazz vibe)\n- Current curated playlist (dinner-focused jazz with a touch of bossa nova and a gentle lift for dancing)\n  1) Garota De Ipanema – Jobim\n  2) Desafinado – Jobim\n  3) Corcovado (Quiet Nights…) – Jobim\n  4) Dindi – Jobim\n  5) O Boto – Jobim\n  6) Samba De Uma Nota Sô – Jobim\n  7) Se Todos Fossem Iguais A Você (Instrumental) – Jobim\n  8) Angela – Jobim\n  9) Canta, Canta Mais – Jobim\n  10) Ligia – Jobim\n  11) Outra Vez – Jobim\n  12) Por Causa De Você – Jobim\n  13) Do What Cha Wanna – Billy Cobham\n  14) Moon Germs – Billy Cobham\n 15) Quadrant – Billy Cobham\n- Total duration: ~56 minutes; cost ~US$14.85 (if you’re pulling from a store catalog)\n- Next steps for music:\n  - I can export this as a CSV or playlist file for your DJ or live musician.\n  - Do you want a live jazz quartet/ensemble for cocktails and dinner in addition to or instead of a DJ?\n  - I  ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic—we’ve got a clear picture: you’re in London, you want a wedding in Paris for 100 guests with a jazz vibe. I’ve pulled together practical options and next steps to lock this in.
#
# What I have gathered and updated
# - Origin: London
# - Destination: Paris
# - Guest count: 100
# - Music mood: Jazz (with a tasteful dinner set, optional live jazz or DJ)
#
# Travel options (planning for guests)
# - Best value direct options from London to Paris (May timing)
#   - LTN → CDG: 13 May 2026, 06:10–08:35, 1h25m, Economy, ~€37, Kiwi booking link: https://on.kiwi.com/NHMV9y
#   - LGW → CDG: 13 May 2026, 16:10–18:30, 1h20m, Economy, ~€44, Kiwi booking link: https://on.kiwi.com/qsC6F4
#   - LGW → CDG: 12 May 2026, 16:50–18:10, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/Qiy1Q2
#   - LGW → CDG: 15 May 2026, 18:00–21:20, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/lXm7Ce
#   - SEN → CDG: 14 May 2026, 10:10–12:20, 1h10m, Economy, ~€49, Kiwi: https://on.kiwi.com/tygfQj
#   - STN → CDG: 15 May 2026, 16:00–19:10, 1h10m, Economy, ~€54, Kiwi: https://on.kiwi.com/sVFB7T
#   - LTN → CDG: 18 May 2026, 19:40–22:00, 1h20m, Economy, ~€44, Kiwi: https://on.kiwi.com/P23g0A
# - Note: These are one-way, economy fare options suitable for a May wedding trip. If you’d rather secure a group block for guests or need specific dates, I can shift to a group quote or suggest alternate dates.
#
# Venue options in Paris for ~100 guests (with capacity and pricing hints)
# - Primary match: Une Salle Paris (Salle 100 Personnes)
#   - Capacity: exactly 100 guests
#   - Price: from ~€1,500 to ~€5,000 (range depends on package; need current quotes)
#   - Source: unesalleaparis.com
#   - Why consider: explicit 100-person capacity in listing; tends to align well with strict guest count
# - Strong near-100 options:
#   - Native Spaces – Paris Event Space
#     - Capacity: up to 100
#     - Price: not listed online (requires direct quote)
#     - Source: native-spaces.com
#   - Le Philanthro-Lab (via SnapEvent)
#     - Capacity: not stated in snippet
#     - Price: from ~€6,750 HT (varies by package)
#     - Reviews: some positive notes
#     - Source: snapevent.fr
# - Additional venues often listed for up to 100 guests (useful if exact capacity is flexible)
#   - Paris venues via Mariages.net and 1001salles, etc. (vary by venue and package)
# What I’d recommend now
# - Primary option to proceed with: Une Salle Paris (Salle 100 Personnes)
#   - Pros: explicit 100-person capacity, potentially the most straightforward for 100 guests
#   - Cons: price varies; need current quotes and date availability
# - Secondary option if you want flexibility or a different vibe: Native Spaces – Paris Event Space
#   - Pros: can host up to 100; modern, modular spaces
#   - Cons: exact capacity and pricing require a direct quote
# Would you like me to:
# - Contact Une Salle Paris and Native Spaces for availability and formal quotes for your preferred May dates?
# - Or would you prefer I also explore a live jazz venue option (jazz quartet/ensemble in a ceremony-dinner format) as part of the venue plan?
#
# Music plan (jazz vibe)
# - Current curated playlist (dinner-focused jazz with a touch of bossa nova and a gentle lift for dancing)
#   1) Garota De Ipanema – Jobim
#   2) Desafinado – Jobim
#   3) Corcovado (Quiet Nights…) – Jobim
#   4) Dindi – Jobim
#   5) O Boto – Jobim
#   6) Samba De Uma Nota Sô – Jobim
#   7) Se Todos Fossem Iguais A Você (Instrumental) – Jobim
#   8) Angela – Jobim
#   9) Canta, Canta Mais – Jobim
#   10) Ligia – Jobim
#   11) Outra Vez – Jobim
#   12) Por Causa De Você – Jobim
#   13) Do What Cha Wanna – Billy Cobham
#   14) Moon Germs – Billy Cobham
#  15) Quadrant – Billy Cobham
# - Total duration: ~56 minutes; cost ~US$14.85 (if you’re pulling from a store catalog)
# - Next steps for music:
#   - I can export this as a CSV or playlist file for your DJ or live musician.
#   - Do you want a live jazz quartet/ensemble for cocktails and dinner in addition to or instead of a DJ?
#   - I can tailor a longer set for dancing if you’d like (e.g., 60–90 minutes for a post-dinner dance).
#
# What I need from you to finalize and move into bookings
# - Date window in May (exact date or a couple of targets)
# - Which flight option you prefer (or if you want a group block for guests)
# - Your preferred venue option (Une Salle Paris or Native Spaces, or both as backups)
# - Music approach: DJ with curated jazz playlist, or live jazz quartet/ensemble (or both)
# - Budget ranges for venue, catering, and overall wedding spend (to tailor quotes)
# - Any other must-haves (ceremony location, religious or civil ceremony needs, guest transfers, decoration style, photography/videography, etc.)
#
# Next steps I can take right away (once you confirm)
# - Reach out to the selected Paris venue(s) for availability and quotes for your May date(s).
# - Request group flight quotes or hold a block for guests if you’d like.
# - Source a suitable jazz musician or DJ aligned to your style (e.g., a jazz quartet for cocktail/dinner, with optional APD for dancing).
# - Prepare a refined wedding day schedule (ceremony, cocktail, dinner, speeches, first dance) aligned to the venue’s layout.
# - Deliver a finalized, shareable itinerary and budget breakdown.
#
# Would you like me to start with securing a venue quote (Une Salle Paris as the primary, and Native Spaces as a backup) and a group flight quote for a couple of May dates? If you share your preferred date(s) and budget range, I’ll tailor the asks and tighten the plan.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
