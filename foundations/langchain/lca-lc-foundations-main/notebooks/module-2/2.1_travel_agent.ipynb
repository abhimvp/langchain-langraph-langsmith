# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on 31/03/2026")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on 31/03/2026', additional_kwargs={}, response_metadata={}, id='3f995ae1-0f11-4813-8886-c4853bcf930b'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 509, 'prompt_tokens': 1232, 'total_tokens': 1741, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI75s2CIWYQoWlOFn5knXnmQKcQYv', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cdb86-615f-7a13-961e-dd8fa54480f6-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'curr': 'USD', 'locale': 'en', 'cabinClass': 'M'}, 'id': 'call_LZRtPba2ZDcxRmhKjUUd0U4X', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1232, 'output_tokens': 509, 'total_tokens': 1741, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n    "durationInSeconds": 98100,\n    "price": 645,\n    "deepLink": "https://on.kiwi.com/6kbr1p",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:25:00.000Z",\n      "local": "2026-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 72000,\n    "durationInSeconds": 72000,\n    "price": 846,\n    "deepLink": "https://on.kiwi.com/K7VSZb",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T23:55:00.000Z",\n          "local": "2026-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T13:25:00.000Z",\n      "local": "2026-04-01T22:25:00.000"\n    },\n    "totalDurationInSeconds": 106500,\n    "durationInSeconds": 106500,\n    "price": 627,\n    "deepLink": "https://on.kiwi.com/wuZhFW",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T02:10:00.000Z",\n          "local": "2026-04-01T10:10:00.000"\n        }\n      },\n      {\n        "at": "CTS",\n        "city": "Sapporo",\n        "cityCode": "SPK",\n        "arrival": {\n          "utc": "2026-04-01T06:00:00.000Z",\n          "local": "2026-04-01T15:00:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T11:50:00.000Z",\n          "local": "2026-04-01T20:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T13:40:00.000Z",\n      "local": "2026-04-01T22:40:00.000"\n    },\n    "totalDurationInSeconds": 107400,\n    "durationInSeconds": 107400,\n    "price": 638,\n    "deepLink": "https://on.kiwi.com/n7GJrI",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T02:10:00.000Z",\n          "local": "2026-04-01T10:10:00.000"\n        }\n      },\n      {\n        "at": "CTS",\n        "city": "Sapporo",\n        "cityCode": "SPK",\n        "arrival": {\n      ...
#               AIMessage(content='Direct flight option found for your date.\n\nCheapest direct options\n| Route | Outbound | Cabin | Return Route | Return Outbound | Return Cabin | Price | Book |\n|---|---|---|---|---|---|---|---|\n| SFO → HND (Non-stop) | 31/03/2026 01:45 → 01/04/2026 05:00 (11h 15m) | Economy |  |  |  | 1776 USD | https://on.kiwi.com/E5esv1 |\n\nShortest direct options\n| Route | Outbound | Cabin | Return Route | Return Outbound | Return Cabin | Price | Book |\n|---|---|---|---|---|---|---|---|\n| SFO → HND (Non-stop) | 31/03/2026 01:45 → 01/04/2026 05:00 (11h 15m) | Economy |  |  |  | 1776 USD | https://on.kiwi.com/E5esv1 |\n\nOther direct options\n(No additional non-stop options found on this date.)\n\nRecommendation\n- Best overall: The direct SFO to Tokyo Haneda (HND) flight on 31/03/2026 offers the simplest and fastest option with no layovers.\n\nBooking link\n- Direct flight: https://on.kiwi.com/E5esv1\n\nHave a wonderful trip! Fun fact: Tokyo is renowned for having more Michelin-starred restaurants than any other city in the world.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4434, 'prompt_tokens': 6226, 'total_tokens': 10660, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 4096, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI762ONmdRb6xTla95MFWoj1qTn3F', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdb86-8647-7b11-a7d4-d75790149415-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6226, 'output_tokens': 4434, 'total_tokens': 10660, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 4096}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Direct flight option found for your date.
#
# Cheapest direct options
# | Route | Outbound | Cabin | Return Route | Return Outbound | Return Cabin | Price | Book |
# |---|---|---|---|---|---|---|---|
# | SFO → HND (Non-stop) | 31/03/2026 01:45 → 01/04/2026 05:00 (11h 15m) | Economy |  |  |  | 1776 USD | https://on.kiwi.com/E5esv1 |
#
# Shortest direct options
# | Route | Outbound | Cabin | Return Route | Return Outbound | Return Cabin | Price | Book |
# |---|---|---|---|---|---|---|---|
# | SFO → HND (Non-stop) | 31/03/2026 01:45 → 01/04/2026 05:00 (11h 15m) | Economy |  |  |  | 1776 USD | https://on.kiwi.com/E5esv1 |
#
# Other direct options
# (No additional non-stop options found on this date.)
#
# Recommendation
# - Best overall: The direct SFO to Tokyo Haneda (HND) flight on 31/03/2026 offers the simplest and fastest option with no layovers.
#
# Booking link
# - Direct flight: https://on.kiwi.com/E5esv1
#
# Have a wonderful trip! Fun fact: Tokyo is renowned for having more Michelin-starred restaurants than any other city in the world.
