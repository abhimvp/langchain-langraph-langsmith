# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to around September 2023 (some topics from late 2023 may appear, but not reliably). I don’t have real-time internet access unless browsing is enabled in this chat. So:
#
# - I’m good with information up to that cutoff and general knowledge after that is uncertain.
# - For anything post-cutoff (news, tech updates, policy changes), I can help you verify with sources if you provide them or if browsing is available. If you want, I can also outline how to check the latest details.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.youtube.com/watch?v=jKlTyBxpyT4',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on,',
#    'score': 0.99861145,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured ...",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.99793327,
#    'raw_content': None},
#   {'url': 'https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/',
#    'title': 'San Francisco Mayor-elect Daniel Lurie claims victory, outlines ...',
#    'content': "San Francisco's Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed",
#    'score': 0.99549675,
#    'raw_content': None},
#   {'url': 'https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election',
#    'title': 'Levi Strauss heir Daniel Lurie elected mayor of San ...',
#    'content': '... San Francisco non-profit he founded. He defeated several Democratic challengers, including the current mayor, London Breed, in an election',
#    'score': 0.99193794,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=WNNWEqONz_E',
#    'title': 'San Francisco Mayor Daniel Lurie: We are open for business',
#    'content': "San Francisco Mayor Daniel Lurie joins 'Power Lunch' to discuss how much AI spending is playing a role in San Francisco's economy.",
#    'score': 0.98959166,
#    'raw_content': None}],
#  'response_time': 0.61,
#  'request_id': '59cdceaf-7b7a-406c-8f19-e7f0819e2643'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='621efa22-2b7a-4417-8aec-c74c81a1c8a9'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 475, 'prompt_tokens': 133, 'total_tokens': 608, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHkgGAQDA4DsqViU7sIyD0ez8Niup', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cd663-bcf4-70b3-9d37-7966d32ea9ee-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'call_2heE0yzF1wsIiSlwBj69QUPZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 475, 'total_tokens': 608, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.8745175, "raw_content": null}, {"url": "https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election", "title": "Levi Strauss heir Daniel Lurie elected mayor of San Francisco", "content": "... San Francisco non-profit he founded. He defeated several Democratic challengers, including the current mayor, London Breed, in an election", "score": 0.8455478, "raw_content": null}, {"url": "https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/", "title": "San Francisco Mayor-elect Daniel Lurie claims victory, outlines ...", "content": "San Francisco\'s Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed", "score": 0.834852, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie - Wikipedia", "content": "Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco,", "score": 0.79196626, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=cu9Cc8TEGog", "title": "SF Mayor Daniel Lurie delivers 1st State of the City address - YouTube", "content": "San Francisco Mayor Daniel Lurie will deliver his first State of the City address, highlighting that the city is \\"on the rise\\" and that", "score": 0.7663815, "raw_content": null}], "response_time": 0.86, "request_id": "620c9d0e-a4a8-405d-bade-e1ef07656cbd"}', name='web_search', id='b011b23b-7ac0-4cce-b5c7-9024fe33583a', tool_call_id='call_2heE0yzF1wsIiSlwBj69QUPZ'),
#  AIMessage(content='Daniel Lurie. He won the 2024 San Francisco mayoral election and is the current mayor.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1118, 'prompt_tokens': 714, 'total_tokens': 1832, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHkgMdyAGGHg4NURnaROfqxpptUiH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd663-d9b6-7602-bdf1-4cf44d4a8cf2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 714, 'output_tokens': 1118, 'total_tokens': 1832, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
print(response['messages'][-1].content)
# Out:
# Daniel Lurie. He won the 2024 San Francisco mayoral election and is the current mayor.
