# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you’re thinking of fiction, some stories invent lunar capitals like “Lunapolis” or similar, but those are fictional.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 440, 'prompt_tokens': 13, 'total_tokens': 453, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHjY8a4p65swjKG7xBZT9VWchbu0C', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd621-65d5-77b1-9668-c74a41a1608d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 440, 'total_tokens': 453, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you’re thinking of fiction, some stories invent lunar capitals like “Lunapolis” or similar, but those are fictional.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DHjY8a4p65swjKG7xBZT9VWchbu0C',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 440,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 384,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 453}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. If you’re thinking of a fictional setting, people sometimes invent names like “Lunopolis” or “Selene City” for a lunar capital. Want me to invent a fictional capital for a story?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
# model = init_chat_model(model="claude-sonnet-4-5")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that Earth does. It's a celestial body, not a country or a populated planet.
#
# However, if we were to imagine a "capital" based on historical significance or scientific importance, some might jokingly point to:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed during the Apollo 11 mission in 1969. It's a hugely significant historical site for humanity's exploration of space.
#
# But in reality, there's no government, no population, and therefore no need for a capital on the Moon.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='09d90d2f-6231-4ebc-b96c-2ec30353d210'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. (In fiction, you might see names like Lunapolis, but that’s just imaginary.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 625, 'prompt_tokens': 13, 'total_tokens': 638, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHjrRlZdzkchw3dnVRcX10a8VNdvE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd633-ab5a-7a42-a0aa-64dd84324650-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 625, 'total_tokens': 638, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. (In fiction, you might see names like Lunapolis, but that’s just imaginary.)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e0e8971a-7e0f-4ffc-b66a-29ab398a6423'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='276f82d5-97ef-46a7-82ad-376ae52fe292', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='5f31b56d-0d1d-4bd6-ad38-8738b3bd6639'),
#               AIMessage(content='Quick correction: there isn’t a real capital of the Moon. Luna City is a fictional concept I can build around. If you want, here’s a detailed, self-contained version of Luna City as a fictional setting.\n\nLuna City: a fictional capital and hub of a lunar federation\n- Location and layout\n  - Situated inside a large lava-tube complex near the Moon’s near side, protected from radiation and micrometeorites.\n  - The city center sits at the crater rim overlooking a pocketed plains area, with residential domes radiating outward like petals.\n  - Ground infrastructure uses networks of tunnels, air-filled connectors, and surface walkways for quick transit between districts.\n\n- Governance and society\n  - Governing body: Lunar Authority, a treaty-based federation with a City Council and a rotating Mayor of Luna City.\n  - Sectors represented: Science & Education, Industry & Mining, Culture & Arts, and Habitat & Transport.\n  - Population: tens of thousands of residents, with a healthy mix of engineers, researchers, medical staff, educators, and service workers; many are permanent residents, with rotating scientist crews.\n\n- Economy and industry\n  - Core resources: water ice mined from permanently shadowed regions (processed into drinking water and oxygen), and helium-3 as a potential energy resource.\n  - Key activities: 3D-printed construction, bioprinting for medical research, solar energy farms supplying the city and surplus to Earth.\n  - Tourism and outreach: guided “dawn tours” of the ice wells, crater rim hikes (inside protective domes), and virtual reality experiences of Earth views.\n\n- Habitat and technology\n  - Architecture: a cluster of geodesic domes and lava-tube halls with regolith shielding, high-efficiency life support, and radiation protection.\n  - Energy: central solar arrays with battery storage and a small modular nuclear or RTG backup for critical systems.\n  - Water and life support: closed-loop hydroponics for food; water extracted from ice, purified, and recycled.\n  - Transport: surface rovers and magnetic-train links between districts; a small airlock-to-asteroid freight shuttle port at the surface for supply runs.\n\n- Culture and daily life\n  - Time and routines: a 14-Earth-day day-night cycle influences work shifts, with most activities running on two primary shifts.\n  - Education and science: universities and research institutes housed in the central dome, with outreach programs to Earth and other colonies.\n  - Arts and community: theater in the Cryo Theater, digital art galleries, music performed in dome acoustics, and festivals celebrating Earth-Moon history.\n\n- Landmarks and notable places\n  - The Lumen Gate: a shimmering entry plaza with a panoramic view of Earth.\n  - Asteria Dome: the largest habitat cluster and research hub.\n  - Ice-Well Plaza: a public square above an accessible ice extraction site.\n  - The Echo Dome: a communications hub where Earth and lunar colonies exchange data streams and cultural media.\n  - Beacon Park: a public green space inside the lava-tube complex with simulated “sunrise” lighting.\n\n- Challenges and resilience\n  - Radiation and micrometeorites: robust shielding, active monitoring, and rapid shelter protocols.\n  - Dust management: airlocks and cleanroom corridors to reduce dust intrusion.\n  - Resource balance: dependence on Earth for some supplies; ongoing efforts to maximize local production and recycling.\n\n- Short sample scene\n  - Dawn over Luna City: solar arrays wake with a faint red glow as the first sunlight leaks into the lava-tube corridors. Engineers move between domes in magnetic-rail shuttles, while a public school tracks Earth’s sunrise in a high-ceiling classroom. A researcher in the Ice-Well Plaza seals a crate of harvested water ice, listening to the distant hum of life-support systems and the soft, distant murmur of people starting their day above ground.\n\nIf you’d like, I can tailor Luna Cit ...

# %% [markdown]
# ## Streaming Output
#
# - About [stream_mode](https://docs.langchain.com/oss/python/langchain/streaming/overview#supported-stream-modes)

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital city on the Moon. There’s no real Luna City today, but it’s a rich setting for stories, games, or worldbuilding. Here’s a detailed, cohesive concept you can use or adapt.
#
# Overview
# - Name: Luna City
# - Role: Capital of the Moon; seat of the Lunar Council and the main administrative, cultural, and economic hub for lunar society.
# - Tone options: Can be envisioned as utopian and high-tech, gritty and cyberpunk, or austere and politically tense. Below is a balanced, adaptable blueprint you can tailor.
#
# Setting and geography
# - Location: A hub along the equatorial belt of the near side, where sunlight is abundant and placement for solar arrays is efficient. The city sits in a large crater basin with natural shielding from micrometeoroids, plus man-made shielding to protect against radiation. The core district is anchored around a central transit hub.
# - Urban footprint: A combination of pressurized domes, hollowed-out crater floors, and surface-grade ring corridors. The core is a cylindrical or toroidal “city within a city” connected to multiple satellite districts by pressurized tubes and vacuum tunnels.
# - Architecture: A mix of basalt-printed structures, glass-faced domes, and tessellated lunar regolith bricks. Buildings use integrated thermal storage, phase-change materials, and flexible solar skin to harvest energy and manage heat. Transparent domes provide daylight while shaded corridors reduce glare and dust infiltration.
# - Environment: Harsh but survivable. Radiation is managed via regolith shielding and active weather control on a micro-scale (dust mitigation, thermal comfort). There is a dust-collection ecosystem and air filtration network. Water is recycled; some is sourced from ice mined in shadowed regions or imported from Earth as a backup.
#
# Governance and society
# - Government: The Lunar Council, comprised of representatives from major lunar districts and sectors (science, industry, culture, agriculture, security, and education). A Chancellor or Prime Administrator leads the executive branch, chosen by the Council or by a lunar-wide referendum, depending on the constitution.
# - Legal system: A lunar constitution guarantees autonomy in internal affairs but includes Earth-Moon cooperative clauses for trade, defense, and international (Earth-Moon) diplomacy. A Civil Forum handles citizens’ rights, civil disputes, and ombudsperson duties. A panel of lunar judges sits in the Lunar Court.
# - Institutions:
#   - The Glass Dome Parliament: where laws are debated; a symbol of transparency with a panoramic view of the crater rim.
#   - The Archives Dome: a vast repository of lunar history, science, and craft, including 3D-printed artifacts and historical holograms.
#   - The Lunar University District: a cluster of universities and research institutes focusing on lunar geology, life support tech, in-situ resource utilization, and microgravity biology.
#   - The Port Quarter: the main commercial and passenger hub, with import/export offices, hydroponic farms, and repair yards.
# - Civil society: A cosmopolitan mix of Earth-born settlers, scientists, artists, engineers, and administratives. Languages commonly spoken include English, Mandarin, Spanish, Arabic, and several lunar-created creoles. Education is highly valued, with strong emphasis on STEM and cross-cultural literacy.
#
# Economy and energy
# - Core industries:
#   - In-situ resource utilization (ISRU): mining regolith for oxygen, metals, and building materials.
#   - Solar energy: vast solar farms on adjacent plateaued rims feed the city with clean power; energy storage to support night cycles.
#   - Water and life support tech: recycling systems, hydroponics, and bioreactors for food and oxygen generation.
#   - Manufacturing and research: additive manufacturing (3D printing) of components from lunar materials; biotech for closed-loop ecosystems; microgravity manufacturing.
#   - Trade with Earth: communications, data services, lunar tourism, and specialized materials (e.g., pristine lunar regolith specimens, glass from regolith, and high-purity metals).
# - Currency and economy: A credit-based economy with a lunar “stable currency” backed partly by energy credits and lunar resources. Digital ledgers, smart contracts, and AI-driven logistics optimize supply chains.
# - Tourism: Space-tourism overflow from Earth, lunar exploration programs, and cultural festivals attract visitors. Attractions include the Sea Gate port, observatories, and open-air experiences under domes.
#
# Technology and infrastructure
# - Transportation:
#   - Surface transit: maglev-like tube trains and vacuum-tube shuttles connect districts.
#   - Vertical ascent: elevator-towers and “Needle” transit lines ferry people between surface hubs and elevated platforms.
#   - Personal mobility: low-gravity vehicles, electric rovers, and foot-pod hoists; in domes, wall-running drones and hover-darts for short trips.
# - Life support: closed-loop systems including hydroponics, bioreactors, air recycling, and thermal control, designed to be resilient to solar outages and micrometeoroid impacts.
# - Safety and resilience: redundant power, radiation shelters, emergency airlocks, and dust-control corridors. Public alerts in multiple languages and clear, practiced evacuation procedures.
# - Communications: a high-bandwidth lunar network linking Earth and Moon, with quantum-encrypted channels for sensitive data and a robust, public information network for citizens.
#
# Culture, daily life, and society
# - Daily life: Residents divide time among work in ISRU labs, education, maintenance of life-support ecosystems, and cultural pursuits. Work shifts are often shifted by district to balance daylight and microgravity work cycles.
# - Education: Strong emphasis on STEM and hands-on training. Schools often partner with the Lunar University District for internships in robotics, geology, biotech, and energy tech.
# - Arts and leisure:
#   - The Crater Opera House and the Aurora Dome host concerts, plays, and space-themed performances.
#   - Lunar festivals celebrate solar cycles, dust storms (as a reminder of resilience), and the discovery of new ISRU techniques.
#   - Museums and holographic galleries display Earth-Moon heritage, lunar geology, and future habitats.
# - Cuisine: Food relies on hydroponics and lab-farmed proteins. Local flavors include algae-based dishes, mineral-rich mineral soups, and lab-grown dairy substitutes. Lunar coffee and tea exist, often with spices sourced from Earth or grown in domed gardens.
#
# Security, defense, and diplomacy
# - Security posture: Civil defense and space police maintain order; no large standing army on Luna City, but rapid-response squads are ready for debris, solar storms, and surface threats.
# - Earth-Moon diplomacy: The city hosts regular summits with Earth-based governments and space agencies. Joint research facilities and shared infrastructure projects are common.
# - Potential tensions: Resource allocation, trade disputes, or debates about autonomy versus Earth oversight. The government keeps a careful balance to maintain stability and trust with Earth authorities.
#
# Key districts and landmarks (sample)
# - The Glass Dome Parliament: the central government complex with crystalline architecture, visible from the crater rim.
# - The Core Atrium: the heart of Luna City, a vertical, light-filled hub with markets, media studios, and the main transit spine.
# - The Archives Dome: a quiet, reflective space where citizens access lunar history and future plans.
# - The Sea Gate Port: the primary docking and freight area, with a man-made harbor, shipyards, and long-range communication towers.
# - Helios Park and Solar Quarter: open-air and indoor parks interwoven with solar canopies; a social and environmental oasis.
# - The Arcology Towers: mixed-use high-rises that house government offices, residences, and research facilities.
# - The Night Forge: a high-tech fabrication district where metal and composite parts are produced.
# - The Observatory Ring: multiple telescopes and sensors for planetary science and solar observation.
# - The Lunar University Cluster: campuses dedicated to science, engineering, medicine, and humanities with generous lab spaces.
#
# History and timeline (highlights you can adapt)
# - Early settlement: Small, independent lunar outposts founded in the early space-age era to harvest ISRU resources.
# - Unification: A coalition forms to unify the lunar settlements into a single governance framework, eventually creating the Lunar Council.
# - Independence and city-building boom: Luna City rises as the political capital; domes and infrastructure expand to support a growing population.
# - The Great Dust Initiative: A major dust-and-dust suppression and infrastructure project that reshapes district layouts and transit lines for safety and efficiency.
# - Earth-Moon collaboration era: Strong treaties and shared research programs establish Luna City as a hub for science and technology in the solar system.
# - Present day: Luna City is a stable, bustling capital with a vibrant culture and a strong focus on resilience, innovation, and autonomy.
#
# Story hooks and plot seeds (if you’re writing fiction)
# - A political scandal ruptures a Lunar Council election; the protagonist uncovers a scheme to siphon ISRU resources to a private corporate faction.
# - A solar flare impacts Luna City’s energy network; engineers race to reroute power while a medical emergency strains the life-support system.
# - A new discovery in the Archives Dome reveals an ancient Earth-based archive predating the Moon’s current governance; the moral question is who should control such knowledge.
# - A diplomatic incident with Earth threatens to destabilize trade routes; a junior diplomat and a rogue AI must navigate a web of factions to avert war.
# - A culture clash plot: a festival celebrating Earth heritage is overshadowed by a dust storm crisis—how do communities come together?
#
# Mood and tone variants you can adopt
# - Utopian high-tech: Clean energy, transparent governance, open access to education, abundant arts, and a thriving civil society.
# - Gritty cyberpunk: Corporate control, surveillance in public spaces, resource scarcity pressures, and a complex black market for tech.
# - Hard sci-fi realism: Realistic physics of low gravity, airlock protocols, dust management as daily life, and a pragmatic approach to governance and infrastructure.
# - Diplomatic thriller: Intrigue among lunar factions, Earth-Moon politics, and a focus on diplomacy and intelligence.
#
# How you can adapt Luna City
# - For a novel: Pick a core character (a council member, a transit engineer, a journalist, or a university researcher) and build scenes around daily life, a key political decision, or a crisis.
# - For a game (RPG): Create factions (government, corporate ISRU, scientists, artists), a map of districts, and missions tied to resource management, diplomacy, and exploration.
# - For a standalone world bible: Flesh out detailed district maps, precise transit schedules, and a legal code excerpt to lend authenticity.
#
# Would you like me to tailor Luna City for a specific medium or vibe? For example:
# - A cyberpunk Luna City with corporate intrigue and street-level life.
# - A hopeful, utopian lunar capital focused on science and culture.
# - A tense political thriller centered on Earth-Moon diplomacy.
# Tell me the tone or medium, and I’ll adapt the details, draft sample scenes, or create a map and district-by-district layout.
