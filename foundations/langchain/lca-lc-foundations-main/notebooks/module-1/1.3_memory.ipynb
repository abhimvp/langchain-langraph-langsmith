# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='f379d16e-47c6-4a9f-85a5-255cdef45fa1'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calming and energizing at the same time. Would you like to chat about something specific? I can help with color ideas, nature and green spaces, practicing English, or share fun facts about the color green.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 514, 'prompt_tokens': 18, 'total_tokens': 532, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI3bpLpWrVPQhF4fa8UQo9OxYZ9VZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdab9-f9a5-7540-91b1-69678879e5e4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 514, 'total_tokens': 532, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='542c5fe8-090d-49a4-9a85-388e0281524d'),
#               AIMessage(content='I don’t know your favorite color yet. Want me to guess, or would you rather tell me a color you like and I’ll help confirm if it could be your favorite?\n\nIf you want a quick guess-game, answer these 3 short questions:\n1) Do you prefer warm colors (red, orange, yellow) or cool colors (blue, green, purple)?\n2) Do you like bright/saturated colors or muted/earth tones?\n3) Are you drawn more to nature-inspired colors (sky blue, forest green, sand) or bold/unusual colors (pink, teal, neon)?\n\nBased on your answers, I’ll pick a color that fits. Or I can just pick a common favorite like blue if you want a fast guess.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1632, 'prompt_tokens': 11, 'total_tokens': 1643, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1472, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI3dI65iL5t1VxyrdQeWUyEVLTIVo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdabb-5dd7-75f0-b308-b43367ff482d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1632, 'total_tokens': 1643, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1472}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='dd945555-3eab-4866-a305-e66d0a057593'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calming and fresh. Do you have a favorite shade, like emerald, olive, or mint? Any green things you especially love (plants, cars, fashion)? If you’d like, I can share fun facts about green or help you pick a green palette for a project.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 591, 'prompt_tokens': 18, 'total_tokens': 609, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI40m2mEHgNdf5UKT4NaKQOGLH4w7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdad1-95f5-7323-aa31-21741c3ace7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 591, 'total_tokens': 609, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='dd945555-3eab-4866-a305-e66d0a057593'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calming and fresh. Do you have a favorite shade, like emerald, olive, or mint? Any green things you especially love (plants, cars, fashion)? If you’d like, I can share fun facts about green or help you pick a green palette for a project.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 591, 'prompt_tokens': 18, 'total_tokens': 609, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI40m2mEHgNdf5UKT4NaKQOGLH4w7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdad1-95f5-7323-aa31-21741c3ace7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 591, 'total_tokens': 609, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f4e10832-ce2a-41f2-9ca0-744a79ad94a2'),
#               AIMessage(content='Your favourite colour is green.\n\nIf you want, I can help you pick a specific shade (emerald, olive, mint) or put together a green color palette for a project.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 366, 'prompt_tokens': 103, 'total_tokens': 469, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DI42TdgAzzwAOamackWFmGUQjeGeP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cdad3-2e51-7cc3-bf6a-f8d692cbba21-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 103, 'output_tokens': 366, 'total_tokens': 469, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}

# %% [markdown]
# - invoke the agent using this common thread id - it retains the memory of our previous conversation and appended it to it's list of messages. So we now have an agent with memory.
