# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Capital: Lunaris Prime
#
# A quick snapshot:
# - Location: Nestled on the equatorial rim of Mare Serenitatis, built into and around a giant crater known as The Crown. Its centerpiece crescent-shaped megastructure dominates the skyline.
# - Architecture: A network of arcologies, glassy domes, and solar-mathered towers. The central monument, the Crescent Spire, pierces the sky and doubles as a solar concentrator and weather-control beacon.
# - Government: Seat of the Lunar Council and the Earth–Moon Accord. The Parliament meets in the Dome of Dawn, with executive halls and orbital comms hubs radiating outward.
# - Culture: A fusion of Earth-born and Moon-born communities—scientists, miners, artists, and engineers. Emphasis on transparency, sustainability, and pioneering research.
# - Transport and life support: Grounded by gravity-stabilized tramways and elevator lifts from polar bases; powered by solar harvesters and ice-plant water loops.
# - Notable feature: The Gallery of Zero-G, a vast public space that hosts exhibitions and experiments in artificial gravity.
#
# If you’d like, I can tailor Lunaris Prime to a particular tone (utopian, corporate-myn, noir, etc.) or relocate it to a polar crater for a different vibe.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'abhi.wip_X_ICON.png', 'type': 'image/png', 'size': 554724, 'content': <memory at 0x000001CD7E98F280>, 'last_modified': datetime.datetime(2026, 3, 9, 16, 30, 38, 547000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# I’ve imagined a capital that fits a vivid sci‑fi world. If you’re okay with it, here’s Caelum, the Sky Gate—the capital of the Ascendant Alliance.
#
# Caelum, the Sky Gate
# - Where it sits: Caelum floats along the edge of a vast plateau in the upper atmosphere of the ocean-world Aurelia. It’s a city-in-constant-motion, tethered to the sea-level world below by gravity wells and a lattice of magnetic anchors. The result is a light, crystalline skyline that hums with ion winds and spray from the planet’s storms.
# - The vibe: a luminous, technical beauty—glass spires, wind-kissed terraces, and bridges that glitter like auroras at night. It feels ancient and new at the same time, a place where memory and machines braid together.
#
# What makes it unique
# - Architecture: Caelum is a chain of overlapping arcologies—disc-like districts stacked above one another—connected by gravity rails and floating promenades. The outer shells are coated with reactive bioluminescent skin that shifts color with weather and mood. Interior spaces are modular, reconfigurable for festivals or emergencies.
# - Government: The city is governed by two bodies that balance each other—the Council of Winds (executive strategy and defense) and the Archivist Court (custodians of history, law, and memory). Decision-making happens in public orbital forums where citizens can stream testimony from the planet below and the city above.
# - Tech at work: Anti-grav towers, photonic mass transit, and a mesh of “memory glass” that records and streams public events for citizens to review. The city harvests energy from solar sails and storm-charged lattices, then distributes it through the arcologies via silent, high-speed conduits.
# - Culture: The people prize transparency, memory, and art that interacts with data. Markets are memory bazaars where narratives are traded as much as goods. Festivals of light—when the bioluminescent skin shifts through colors—signal seasons and elections.
# - Language and people: A mix of planetary settlers and orbit-born citizens. The common tongue blends spoken language with a code-like humor that’s comfortable with abstraction and improvisation.
#
# Key districts
# - The Spindle Quarter: the nerve center of governance and diplomatic reception. Heightened security there, but openness as you ascend toward the sky-facing terraces.
# - The Glass Markets: commerce hub where craftsmen trade modules, memory crystals, and wind-harvest tech. Everything is recyclable, modular, and endlessly reconfigurable.
# - The Choir of Winds: a communications and culture district where broadcasters, poets, and researchers tune the city’s “voice” to match the weather and mood of Aurelia.
# - The Archive Nebula: a vast complex of memory vaults, digital libraries, and holographic museums. Access to old events is highly ceremonial; new data is curated with care, to avoid overload.
# - The Lumen Dome: a massive energy hub made of transparent insulators and solar sails; it glows visibly across the planet when storms roll in.
#
# Landmarks and scenes
# - Spiral Spire: a towering, rotating observatory that maps Aurelia’s climate and arcs across the horizon. It doubles as a weather control point during storms.
# - The Mirror Dome: a huge hemispherical plaza where the city’s memories are projected as shimmering mazes of light for festivals.
# - The Bridge of Echoes: a translucent sky-bridge that carries goods and people while recording every step as a living memory trail.
# - The Sea-Sail Gate: a tidal gate that channels energy from the ocean below to the city’s lattice. When opened, it creates a spectacular cascade of light.
#
# Life in Caelum
# - Transportation: gravity rails, glide pods that skim along wind currents, and vertical ascent capsules. People move quickly, but there’s a strong culture of lingering in public spaces to observe the sky.
# - Daily life: breakfasts of bio-luminescent fruit, late-night debates in the Market, and quarterly “memory audits” where citizens review a personal or national memory to understand collective history.
# - Economy: the city runs on a blend of data services, memory rights, and wind- or solar-generated energy. Craft is highly valued—modular architecture, memory crystals, and aesthetic tech.
# - Climate and environment: weather is a constant factor. The Archivists tune the atmosphere for comfort and safety, yet the city’s outer surface remains a dynamic, living skin that changes with the planet’s moods.
#
# History and politics in brief
# - Founding myth: Caelum rose after a great storm that threatened Aurelia’s orbiting settlements. The city was built to be resilient, adaptable, and compliant with planetary ecology.
# - Power dynamics: the Council of Winds negotiates with the Archivist Court over access to memory and narrative control. Debates can be dramatic, but public forums keep the process transparent.
# - Tensions: some fear overreliance on memory data can dull spontaneity; others argue that memory is the strongest defense against tyranny. Debates often become public art, with light and sound performances that encode policies.
#
# If you want, I can tailor Caelum to your world:
# - Name and origin of the world (earth-like, gas giant, underwater city, etc.)
# - tech level (early space age, post-scarcity, bio-tech era)
# - political structure (monarchy, republic, technocracy, etc.)
# - mood (hopeful, dystopian, romantic, mythic)
#
# Would you like me to adapt Caelum to a different vibe or name, or write a short scene set there to give you a feel for the capital in action?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.80it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# I noticed there was no content in the audio file you provided. It seems to be silent or not containing any discernible sound. If you're encountering issues, feel free to share more details, and I'll assist further!
